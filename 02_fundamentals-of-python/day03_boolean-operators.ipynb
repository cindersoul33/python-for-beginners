# %%
#boolean operators

condition1 = True
condition2 = False

print(not condition1)
print(condition1 and condition2)
print(condition1 or condition2)
# Out:
# False
# False
# True

# %%
print(0 or 1)
# Out:
# 1

# %%
print(False or "hey")
# Out:
# hey

# %%
print("hi" or "hey")
# Out:
# hi

# %%
print([] or False)
# Out:
# False

# %%
print(False or [])
# Out:
# []

# %%
#or trả về giá trị thật truthy đầu tiên (nếu có) 
#hoặc trả về giá trị falsy (cuối cùng) nếu tất cả đều cùng là falsy.

# %%
print(0 and 1) # falsy and truthy
# Out:
# 0

# %%
print(1 and 0) #truthy and falsy
# Out:
# 0

# %%
print(False and "hey") #falsy and truthy
# Out:
# False

# %%
print("hi" and "hey") #truthy and truthy
# Out:
# hey

# %%
print([] and False) #falsy and falsy
# Out:
# []

# %%
print(False and []) #falsy and falsy
# Out:
# False

# %%
#toán tử and trả về giá trị falsy (nếu có) đầu tiên,
#hoặc trả về giá trị truthy cuối cùng (nếu tất cả đều là truthy)

# %%
#and ưu tiên falsy
#or ưu tiên truthy
