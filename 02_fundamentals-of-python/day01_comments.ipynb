# %%
#test ghi chú
name = "Cindy" #gán giá trị cho biến name
print(name) #in biến name
# Out:
# Cindy

# %%
#variables
name = "Cindy"
age = 31

# %%
#expression and statements

# %%
#data types

# %%
name = "Cindy" #str string
age = 31 #int integer
print(type(name) == str)
print(type(age))
print(isinstance(name, int))
# Out:
# True
# <class 'int'>
# False

# %%
# test ham isinstance
name = 123

if isinstance(name, str): #hàm isinstance kiểm tra, kiểm tra name có phải là string ko?
    print(f"Xin chào {name}")
else:
    print("Tên phải là chuỗi!")
# Out:
# Tên phải là chuỗi!
