# %%
suit = "hearts"
rank = "K"

print ("Your card is: " + rank + " of " + suit)
# Out:
# Your card is: K of hearts

# %%
suits = ["spades", "clubs", "hearts", "diamonds"]
suit = suits[2]
rank = "K"

print("Your card is: " + rank + " of " + suit)
# Out:
# Your card is: K of hearts

# %%
suits = ["spades", "clubs", "hearts", "diamonds"] #list of suits

for suit in suits: #with each suit in suits (for loop)
    print(suit) #print suit
# Out:
# spades
# clubs
# hearts
# diamonds

# %%
suits = ["spades", "clubs", "hearts", "diamonds"]
suits.append("snakes")

for suit in suits:
    print(suit)
# Out:
# spades
# clubs
# hearts
# diamonds
# snakes
